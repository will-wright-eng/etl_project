# %%
# https://www.kaggle.com/dgawlik/nyse
# https://www.kaggle.com/worldbank/world-development-indicators
# https://www.kaggle.com/START-UMD/gtd

# %%
# %reset -f

# import os
# import csv
# import pandas as pd

# # filepath = 'Homework/HeroesOfPymoli/Resources/purchase_data.csv'
# # pd.read_csv(filepath)

# filepath = 'Homework/PyCitySchools/Resources/schools_complete.csv'
# df1 = pd.read_csv(filepath)

###

# import os

# # This is the path where you want to search
# # path = '/Documents/BerkeleyBootcamp/Homework'

# # this is the extension you want to detect
# extension = '.csv'

# for root, dirs_list, files_list in os.walk(path):
#     #print(file_list)
#     for file_name in files_list:
#         #print(filename)
#         if os.path.splitext(file_name)[-1] == extension:
#             file_name_path = os.path.join(root, file_name)
#             print (file_name)
#             print (file_name_path)   # This is the full path of the filter file

# %%
# %reset -f

import csv
import os
import glob
import pandas as pd

cwd = os.getcwd()
path = '/Users/williamwright/Documents/BerkeleyBootcamp/Homework/etl_homework'
extension = 'csv'
os.chdir(path)
result = glob.glob('*.{}'.format(extension))
print(result)

dfs = {}
for i in range(0,len(result)):
    dfs[i]=pd.read_csv(result[i],encoding = "ISO-8859-1")
    display(dfs[i].head())
    print(len(dfs[i]))
    print(list(dfs[i]))
    
# len(dfs)
# Out:
# ['globalterrorismdb_0718dist.csv', 'fundamentals.csv', 'Country.csv', 'country_codes.csv']
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
# # Python program to illustrate the intersection 
# # of two lists in most simple way 
# def intersection(lst1, lst2): 
#     lst3 = [value for value in lst1 if value in lst2] 
#     return lst3 
  
# # Driver Code 
# # lst1 = [4, 9, 1, 17, 11, 26, 28, 54, 69] 
# # lst2 = [9, 9, 74, 21, 45, 11, 63, 28, 26] 
# lst1 = list(dfs[0])
# lst2 = list(dfs[1])
# lst3 = list(dfs[2])
# print(intersection(lst1, lst2))
# print(intersection(lst2, lst3))
# print(intersection(lst1, lst3))

# %%
# display(lst1,lst2,lst3)

for i in range(0,len(dfs)):
    print([x for x in list(dfs[i]) if 'country' in x])
    print([x for x in list(dfs[i]) if 'Country' in x])
    print(len(dfs[i]))
#     dfs[i]=pd.read_csv(result[i],encoding = "ISO-8859-1")
#     display(dfs[i].head())
#     print(len(dfs[i]))
#     print(list(dfs[i]))
# Out:
# ['country', 'country_txt', 'kidhijcountry']
# []
# 181691
# []
# []
# 1781
# []
# ['CountryCode']
# 247
# []
# ['Country']
# 249

# %%
# # Initialize PyMongo to work with MongoDBs
# conn = 'mongodb://localhost:27017'
# client = pymongo.MongoClient(conn)
# # Define database and collection
# db = client.craigslist_db
# collection = db.items

# %%
df = dfs[2].merge(dfs[3],how='left',left_on='CountryCode',right_on='Alpha-3 code')#.count()
# df = df
# df_dict = df.to_dict()
# df_dict

ndf = df.set_index('CountryCode')
cols = list(ndf)
ndf_dict_list = {}
for col in cols:
    ndf_dict_list[col] = list(ndf[col])

# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
# mydb = myclient["mydatabase"]
# mycol = mydb["stuff"]
# Define database and collection
db = client.stuff
collection = db.items

# db.createCollection('stuff',df_dict)
# collection.insert_many(ndf_dict_list)
collection.insert_one(ndf_dict_list)

# # Loop through returned results
# for row in df_dict:
#     print(row)
#     collection.insert_one(df_dict[row])
# #     print(df_dict[row])

# %%
db.list_collection_names()
# Out:
# ['items']

# %%
from pymongo import MongoClient

# if __name__ == '__main__':
#     client = MongoClient("localhost", 27017, maxPoolSize=50)
#     db = client.localhost
#     collection = db['items']
#     cursor = collection.find({})
#     for document in cursor:
#           print(document)

collection = db['items']
cursor = collection.find({})
for document in cursor:
      print(document)

# %%
collection['items']
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, maxpoolsize=50), 'localhost'), 'items.items')

# %%
# ndf_dict_list
# collection.insert_one(ndf_dict_list)
